# %% [markdown]
# # **Домашна №1**

# %% [markdown]
# ### 1. Задължително изгледайте [M4ML - Linear Algebra](https://www.youtube.com/playlist?list=PLiiljHvN6z1_o1ztXTKWPrShrMrBLo5P3) за следващия път!

# %% [markdown]
# ### 2. Ако желаете да си изтеглите и разгледате вкъщи решенията на алгоритмите, разглеждани днес, ще трябва да си изтеглите Jupyter и Jupyter Notebook :D
