# %% [markdown]
# # **Въведение в Jupyter**
# - Install: [link](https://jupyter.org/install)

# %% [markdown]
# #### **Когато гледате курса на *Imperial College London*, отворете си notebook и имплементирайте дефинициите, понятията и теоремите, докато гледате видеата!**

# %% [markdown]
# - Как се прави нова клетка? **Горе \'+\'**
# - Как се изпълнява? **Shift + Enter**
# - Markdown Cheat Sheet: [click link here](https://www.markdownguide.org/cheat-sheet/)
