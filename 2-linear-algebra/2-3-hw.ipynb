# %% [markdown]
#  # **Домашна №2**

# %% [markdown]
# ### Задължително изгледайте видеата от 1.1. до 4.1 от [M4ML - Multivariate Calculus](https://www.youtube.com/playlist?list=PLiiljHvN6z1_o1ztXTKWPrShrMrBLo5P3) за следващия път!
