# %% [markdown]
#  # **Домашна №3**

# %% [markdown]
# ### Изгледайте видеата от 4.1 до края от [M4ML - Multivariate Calculus](https://www.youtube.com/playlist?list=PLiiljHvN6z1_o1ztXTKWPrShrMrBLo5P3) за следващия път!
