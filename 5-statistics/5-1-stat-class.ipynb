# %% [markdown]
# # **Статистика**

# %% [markdown]
# ## **Зад 1. Проверка за вътрешно произведение**
# - Дефинирайте трите булеви функции:
#     - `is_symmetric(f)` - проверява дали функцията `f(x,y)` е симетрична т.е. `f(x,y)` = `f(y,x)`;
#     - `is_positive_definite(f)` - проверява дали `f(x,x) >= 0`;
#     - `is_bilinear(f)` - проверява билинейността на `f(x,y)`, т.е. линейността спрямо всеки аргумент.
# - Намерете функция `f(x,y)`, различна от скаларното произведение, която да изпълнява трите условия.

# %%
import numpy as np

# Данни за тестване
x_test = np.array([1, 2, 3, 5])
y_test = np.array([1, 2, 4, 6])

def is_symmetric(f):
    # write code here
    return False

def is_positive_definite(f):
    # write code here
    return False

lam = 2 
w_test = np.array([1, 2, 6, 7])
def is_bilinear(f):
    # write code here
    return False

def f(x, y):
    # switch function
    return np.dot(x,y)

if is_symmetric(f) and is_positive_definite(f) and is_bilinear(f):
    print("f е вътрешно произведение")
else:
    if not is_symmetric(f):
        print("f не е симетрична")
    if not is_positive_definite(f):
        print("f не е положително дефинирана")
    if not is_bilinear(f):
        print("f не е билинейна")
# Out:
# f не е симетрична
# f не е положително дефинирана
# f не е билинейна

# %% [markdown]
# ## **Зад 2. Теоремата на Питагор**
# - Имплементирайте:
# $$
# \langle x, y \rangle := \operatorname{cov}(x, y)
# $$
#
# $$
# \|x\| = \sqrt{\langle x, x \rangle} = \sqrt{\operatorname{cov}(x, x)} = \sigma(x)
# $$
#
# $$
# If \quad \cos \theta = \frac{\langle x, y \rangle}{\|x\| \, \|y\|} = \frac{\operatorname{cov}(x, y)}{\sigma(x)\sigma(y)} = 0
# $$
#
# $$
# Then \quad \|x + y\|^2 = \|x\|^2 + \|y\|^2 \quad \Rightarrow \quad
# \sigma^2(x + y) = \sigma^2(x) + \sigma^2(y)
# $$
#
# $$
# \sigma(x+y) = \sqrt{\sigma^2(x) + \sigma^2(y)}
# $$

# %%
import numpy as np

x = np.array([1, -1, 0, 0])
y = np.array([0, 0, 1, -1])

# Центриране премахва средната стойност от данните, което гарантира, 
# че ковариацията и вътрешното произведение измерват само линейните зависимости между отклоненията.
x_centered = x - np.mean(x)
y_centered = y - np.mean(y)

# write code here

print("cos(theta) =", cos_theta)

def pythagoras_theorem(norm_x, norm_y, inner_product):
    # write code here

if (cos_theta == 0):
    sigma_sum = # write code here
    print("Питагоровата теорема е в сила.")
else:
    print("Питагоровата теорема не е в сила.")
# Out:
#   Cell In[67], line 16
#     sigma_sum = # write code here
#     ^
# IndentationError: expected an indented block after function definition on line 13

# %% [markdown]
# ## **Зад 3. Непознат код**
# - Обяснете какво прави този код.
# ``` txt
# include stdout
#
# allow -> (matrix(int)) A
# A.fillRow(2, 1)
# A.fillRow(1, 3)
#
# allow -> (float) detA
# detA = A.calcDeterminant(A)
#
# allow -> (vector(float)) characVals
# characVals = A.calcCharacterValues(detA)
#
# allow -> (matrix(float)) characVecs
# characVecs = A.calcCharacterVectors(A, characVals)
#
# allow -> (int) i
# as-long-as: characVals not EMPTY
#     stdout(characVals[i], NEW_ROW)
#     i.increment()
#
# allow -> (int) j
# as-long-as: characVecs not EMPTY
#     stdout(characVecs[j], NEW_ROW)
#     j.increment()
# ```
